# %%
import pandas as pd
import datetime as date
import datetime as datetime

# %%
#MATT STARTS HERE

# %%
london_201718 = pd.read_csv('Resources/2017-18-1.csv', encoding = "ISO-8859-1")
london_201718.head()
# Out:
#   Itinerary ID Travel Date              Traveller Name   Type  \
# 0     C00744FX  21/09/2017   Anderson, Barry (2210736)  Train
# 1     C007VXX9  27/02/2018   Anderson, Barry (2210736)  Train
# 2     C00744FX  21/09/2017    Bentley, Susan (1096721)  Train
# 3     C007B7ST  07/11/2017  Blackburn, David (2379048)  Train
# 4     C007B7ST  07/11/2017  Blackburn, David (2379048)  Train
#
#    Trip Length Days  Total £  Net £  VAT £                          Detail  \
# 0               0.0     17.1   17.1    0.0       V007XVKY Horsforth - York
# 1               0.0      8.0    8.0    0.0  V008QHPP Horsforth - Harrogate
# 2               0.0     17.1   17.1    0.0       V007XVKZ Horsforth - York
# 3               0.0    154.5  154.5    0.0        V0084G60 Leeds - Reading
# 4               0.0     55.0   55.0    0.0        V0084G62 Reading - Leeds
#
#                                    Reason for travel
# 0                        Conference - as an attendee
# ...

# %%
london1_df = london_201718[['Travel Date', 'Type', 'Trip Length Days', 'Reason for travel']].copy()
# Rename the column headers
london1_df = london1_df.rename(columns={"Type": "Travel Type"})

london1_df
# Out:
#    Travel Date Travel Type  Trip Length Days  \
# 0   21/09/2017       Train               0.0
# 1   27/02/2018       Train               0.0
# 2   21/09/2017       Train               0.0
# 3   07/11/2017       Train               0.0
# 4   07/11/2017       Train               0.0
# ..         ...         ...               ...
# 92  07/11/2017       Train               0.0
# 93  07/11/2017       Train               0.0
# 94  12/12/2017       Train               0.0
# 95  30/01/2018       Train               0.0
# 96  30/01/2018       Train               0.0
#
#                                     Reason for travel
# 0                         Conference - as an attendee
# 1                         Conference - as an attendee
# 2                         Conference - as an attendee
# 3   Member portfolio/Council business (Elected Mem...
# 4   Member portfolio/Council business (Elected Mem...
# ..                                                ...
# ...

# %%
grouped_type1 = london1_df.groupby(['Travel Type']).count()
grouped_type1
# Out:
#              Travel Date  Trip Length Days  Reason for travel
# Travel Type
# Ancillary              1                 0                  1
# Flight                 2                 2                  2
# Hotel                  5                 5                  5
# Train                 89                89                 89

# %%
london1_df.drop(london1_df.loc[london1_df['Travel Type']=='Hotel'].index, inplace=True)
london1_df
# Out:
#    Travel Date Travel Type  Trip Length Days  \
# 0   21/09/2017       Train               0.0
# 1   27/02/2018       Train               0.0
# 2   21/09/2017       Train               0.0
# 3   07/11/2017       Train               0.0
# 4   07/11/2017       Train               0.0
# ..         ...         ...               ...
# 92  07/11/2017       Train               0.0
# 93  07/11/2017       Train               0.0
# 94  12/12/2017       Train               0.0
# 95  30/01/2018       Train               0.0
# 96  30/01/2018       Train               0.0
#
#                                     Reason for travel
# 0                         Conference - as an attendee
# 1                         Conference - as an attendee
# 2                         Conference - as an attendee
# 3   Member portfolio/Council business (Elected Mem...
# 4   Member portfolio/Council business (Elected Mem...
# ..                                                ...
# ...

# %%
grouped_type1 = london1_df.groupby(['Travel Type']).count()
grouped_type1
# Out:
#              Travel Date  Trip Length Days  Reason for travel
# Travel Type
# Ancillary              1                 0                  1
# Flight                 2                 2                  2
# Train                 89                89                 89

# %%
london1_df.reset_index(drop=True, inplace=True)
london1_df
# Out:
#    Travel Date Travel Type  Trip Length Days  \
# 0   21/09/2017       Train               0.0
# 1   27/02/2018       Train               0.0
# 2   21/09/2017       Train               0.0
# 3   07/11/2017       Train               0.0
# 4   07/11/2017       Train               0.0
# ..         ...         ...               ...
# 87  07/11/2017       Train               0.0
# 88  07/11/2017       Train               0.0
# 89  12/12/2017       Train               0.0
# 90  30/01/2018       Train               0.0
# 91  30/01/2018       Train               0.0
#
#                                     Reason for travel
# 0                         Conference - as an attendee
# 1                         Conference - as an attendee
# 2                         Conference - as an attendee
# 3   Member portfolio/Council business (Elected Mem...
# 4   Member portfolio/Council business (Elected Mem...
# ..                                                ...
# ...

# %%
london1_df.rename(columns= {'Travel Date': 'Travel_Date',
                           'Travel Type': 'Travel_Type',
                           'Trip Length Days':'Trip_Length_Days',
                           'Reason for travel':'Reason_for_Travel'}, inplace=True)

london1_df
# Out:
#    Travel_Date Travel_Type  Trip_Length_Days  \
# 0   21/09/2017       Train               0.0
# 1   27/02/2018       Train               0.0
# 2   21/09/2017       Train               0.0
# 3   07/11/2017       Train               0.0
# 4   07/11/2017       Train               0.0
# ..         ...         ...               ...
# 87  07/11/2017       Train               0.0
# 88  07/11/2017       Train               0.0
# 89  12/12/2017       Train               0.0
# 90  30/01/2018       Train               0.0
# 91  30/01/2018       Train               0.0
#
#                                     Reason_for_Travel
# 0                         Conference - as an attendee
# 1                         Conference - as an attendee
# 2                         Conference - as an attendee
# 3   Member portfolio/Council business (Elected Mem...
# 4   Member portfolio/Council business (Elected Mem...
# ..                                                ...
# ...

# %%
#ZACH STARTS HERE

# %%
london_df = pd.read_csv('Resources/international-visitors-london-raw.csv', encoding = "ISO-8859-1")
london_df
# Out:
#         year         quarter        market     dur_stay mode        purpose  \
# 0       2002   January-March       Belgium  1-3  nights  Air        Holiday
# 1       2002   January-March       Belgium  1-3  nights  Air       Business
# 2       2002   January-March       Belgium  1-3  nights  Air            VFR
# 3       2002   January-March       Belgium  1-3  nights  Air  Miscellaneous
# 4       2002   January-March       Belgium  1-3  nights  Sea       Business
# ...      ...             ...           ...          ...  ...            ...
# 59799  2019P  July-September  Other Africa  8-14 nights  Air          Study
# 59800  2019P  July-September  Other Africa  15+  nights  Air        Holiday
# 59801  2019P  July-September  Other Africa  15+  nights  Air       Business
# 59802  2019P  July-September  Other Africa  15+  nights  Air            VFR
# 59803  2019P  July-September  Other Africa  15+  nights  Air  Miscellaneous
#
# ...

# %%
clean_london = pd.read_csv('Resources/london_17-18.csv', encoding = "ISO-8859-1")
clean_london
# Out:
#       year           quarter        market     dur_stay mode        purpose  \
# 0     2017     January-March       Belgium  1-3  nights  Air        Holiday
# 1     2017     January-March       Belgium  1-3  nights  Air       Business
# 2     2017     January-March       Belgium  1-3  nights  Air  Miscellaneous
# 3     2017     January-March       Belgium  1-3  nights  Sea        Holiday
# 4     2017     January-March       Belgium  1-3  nights  Sea       Business
# ...    ...               ...           ...          ...  ...            ...
# 6240  2018  October-December  Other Africa  8-14 nights  Air        Holiday
# 6241  2018  October-December  Other Africa  8-14 nights  Air       Business
# 6242  2018  October-December  Other Africa  8-14 nights  Air            VFR
# 6243  2018  October-December  Other Africa  15+  nights  Air       Business
# 6244  2018  October-December  Other Africa  15+  nights  Air            VFR
#
# ...

# %%
clean_london.columns
# Out:
# Index(['year', 'quarter', 'market', 'dur_stay', 'mode', 'purpose', 'area',
#        'Visits (000s)', 'Spend (£m)', 'Nights (000s)', 'sample'],
#       dtype='object')

# %%
clean_london = clean_london.drop(columns=['quarter','market','area','Visits (000s)','Spend (£m)','Nights (000s)','sample'])
clean_london
# Out:
#       year     dur_stay mode        purpose
# 0     2017  1-3  nights  Air        Holiday
# 1     2017  1-3  nights  Air       Business
# 2     2017  1-3  nights  Air  Miscellaneous
# 3     2017  1-3  nights  Sea        Holiday
# 4     2017  1-3  nights  Sea       Business
# ...    ...          ...  ...            ...
# 6240  2018  8-14 nights  Air        Holiday
# 6241  2018  8-14 nights  Air       Business
# 6242  2018  8-14 nights  Air            VFR
# 6243  2018  15+  nights  Air       Business
# 6244  2018  15+  nights  Air            VFR
#
# [6245 rows x 4 columns]

# %%
clean_london.rename(columns={'year':'Travel_Date','dur_stay':'Trip_Length_Days','purpose':'Reason_for_travel','mode':'Travel_Type'},inplace=True)
clean_london
# Out:
#       Travel_Date Trip_Length_Days Travel_Type Reason_for_travel
# 0            2017      1-3  nights         Air           Holiday
# 1            2017      1-3  nights         Air          Business
# 2            2017      1-3  nights         Air     Miscellaneous
# 3            2017      1-3  nights         Sea           Holiday
# 4            2017      1-3  nights         Sea          Business
# ...           ...              ...         ...               ...
# 6240         2018      8-14 nights         Air           Holiday
# 6241         2018      8-14 nights         Air          Business
# 6242         2018      8-14 nights         Air               VFR
# 6243         2018      15+  nights         Air          Business
# 6244         2018      15+  nights         Air               VFR
#
# [6245 rows x 4 columns]

# %%
#ALFRED STARTS HERE

# %%
#Raeding my csv in panda
data_file = "Resources/2018-19.csv"
df = pd.read_csv(data_file, encoding = "ISO-8859-1")

# %%
#reducing my dataframe 
travel_data1819 = df[['Travel Date','Travel Type',
       'Trip Length (Days)',
       'Reason for travel']]
travel_data1819
# Out:
#     Travel Date Travel Type  Trip Length (Days)  \
# 0    06/12/2018      Flight                 1.0
# 1    06/12/2018       Hotel                 1.0
# 2    05/04/2018       Train                 0.0
# 3    26/04/2018       Hotel                 1.0
# 4    26/04/2018       Train                 1.0
# ..          ...         ...                 ...
# 129  26/03/2019       Train                 NaN
# 130  07/09/2018       Hotel                 1.0
# 131  07/09/2018       Train                 1.0
# 132  26/10/2018       Train                 0.0
# 133  29/03/2019       Train                 NaN
#
#                                      Reason for travel
# 0       Meeting with other public sector organisations
# 1       Meeting with other public sector organisations
# 2    Member portfolio/Council business (Elected Mem...
# 3    Member portfolio/Council business (Elected Mem...
# 4    Member portfolio/Council business (Elected Mem...
# ...

# %%
#grouping my dataframe by travel type to figure out potential outliers
grouped_type = travel_data1819.groupby(['Travel Type']).count()
grouped_type
# Out:
#              Travel Date  Trip Length (Days)  Reason for travel
# Travel Type
# Flight                 2                   2                  2
# Hotel                 11                  11                 11
# Train                121                 104                121

# %%
#dropping the rows that have the travel type of "Hotel" since its not a maens of transportation
travel_data1819.drop(travel_data1819.loc[travel_data1819['Travel Type']=='Hotel'].index, inplace=True)
# Out:
# C:\Users\Steel\.conda\envs\pythonData\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
#confirm hotelas are dropped 
grouped_type = travel_data1819.groupby(['Travel Type']).count()
grouped_type
# Out:
#              Travel Date  Trip Length (Days)  Reason for travel
# Travel Type
# Flight                 2                   2                  2
# Train                121                 104                121

# %%
#resetting index of data frame 
travel_data1819.reset_index(drop=True, inplace=True)
travel_data1819
# Out:
#     Travel Date Travel Type  Trip Length (Days)  \
# 0    06/12/2018      Flight                 1.0
# 1    05/04/2018       Train                 0.0
# 2    26/04/2018       Train                 1.0
# 3    09/05/2018       Train                 0.0
# 4    23/05/2018       Train                 0.0
# ..          ...         ...                 ...
# 118  26/03/2019       Train                 NaN
# 119  26/03/2019       Train                 NaN
# 120  07/09/2018       Train                 1.0
# 121  26/10/2018       Train                 0.0
# 122  29/03/2019       Train                 NaN
#
#                                      Reason for travel
# 0       Meeting with other public sector organisations
# 1    Member portfolio/Council business (Elected Mem...
# 2    Member portfolio/Council business (Elected Mem...
# 3    Member portfolio/Council business (Elected Mem...
# 4    Member portfolio/Council business (Elected Mem...
# ...

# %%
#renaming my columns in df 
travel_data1819.rename(columns= {'Travel Date': 'Travel_Date',
                           'Travel Type': 'Travel_Type',
                           'Trip Length (Days)':'Trip_Length_Days',
                           'Reason for travel':'Reason_For_Travel'}, inplace=True)
travel_data1819
# Out:
# C:\Users\Steel\.conda\envs\pythonData\lib\site-packages\pandas\core\frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#     Travel_Date Travel_Type  Trip_Length_Days  \
# 0    06/12/2018      Flight               1.0
# 1    05/04/2018       Train               0.0
# 2    26/04/2018       Train               1.0
# 3    09/05/2018       Train               0.0
# 4    23/05/2018       Train               0.0
# ..          ...         ...               ...
# 118  26/03/2019       Train               NaN
# 119  26/03/2019       Train               NaN
# 120  07/09/2018       Train               1.0
# 121  26/10/2018       Train               0.0
# 122  29/03/2019       Train               NaN
#
#                                      Reason_For_Travel
# ...

# %%
data_file = "Resources/London1_df.csv"
travel_17 = pd.read_csv(data_file, encoding = "ISO-8859-1")

# %%
travel_data1819
# Out:
#     Travel_Date Travel_Type  Trip_Length_Days  \
# 0    06/12/2018      Flight               1.0
# 1    05/04/2018       Train               0.0
# 2    26/04/2018       Train               1.0
# 3    09/05/2018       Train               0.0
# 4    23/05/2018       Train               0.0
# ..          ...         ...               ...
# 118  26/03/2019       Train               NaN
# 119  26/03/2019       Train               NaN
# 120  07/09/2018       Train               1.0
# 121  26/10/2018       Train               0.0
# 122  29/03/2019       Train               NaN
#
#                                      Reason_For_Travel
# 0       Meeting with other public sector organisations
# 1    Member portfolio/Council business (Elected Mem...
# 2    Member portfolio/Council business (Elected Mem...
# 3    Member portfolio/Council business (Elected Mem...
# 4    Member portfolio/Council business (Elected Mem...
# ..                                                 ...
# ...

# %%
travel_data1819.to_csv("Resources/Cleaned1819.csv", index=False, header=True)

# %%
clean_london.to_csv('Resources/London_DF.csv', index=True)

# %%
combined_csv = pd.read_csv('Resources/combined_csv.csv')

# %%
#adds the index to the combined_csv
combined_csv = pd.read_csv('Resources/combined_csv.csv')
combined_csv.to_csv('Resources/combined_csv.csv', index=True)
